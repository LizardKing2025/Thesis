# %%
# Libraries
from google.colab import drive
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, SimpleRNN, GRU
from tensorflow.keras.optimizers import RMSprop # Optimizer
import tensorflow as tf
from pickle import load
from google.colab import drive
import math
from sklearn.metrics import mean_squared_error
import numpy as np
from numpy import array
from keras.layers import Bidirectional
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

# %%
# Load data and print examples
drive.mount('/content/drive')
Ruta_Archivo = '/content/drive/MyDrive/Ventas_Hora_V2.csv'
# Out:
# Mounted at /content/drive

# %%
# Load data
Datos=pd.read_csv(Ruta_Archivo,header=0, sep=";", decimal=".")
Datos.head()
# Out:
#   Fecha  Q_Ventas
# 0   1-6        10
# 1   1-7        29
# 2   1-8        68
# 3   1-9        60
# 4  1-10        58

# %% [markdown]
# Definición de CPU como device.

# %%
device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cpu'

# %%
plt.plot(Datos['Q_Ventas'], color= 'black')

# %%
#Datos['Fecha'] = pd.to_datetime(
 #   Datos['Fecha'],
  #  format = '%d.%m.%Y'
#)

#plt.plot(Datos['Fecha'], Datos['Q_Ventas'])

# %%
# Make date index

#Datos = Datos.set_index('Fecha')

# %% [markdown]
# Función para crear lags en el dataset

# %%
from copy import deepcopy as dc

def prepare_dataframe(df, n_steps):
    df = dc(Datos)

    df.set_index('Fecha', inplace=True)

    for i in range(1, n_steps+1):
        Datos[f'Q_Ventas(t-{i})'] = Datos['Q_Ventas'].shift(i)

    df.dropna(inplace=True)

    return df

# %%
TimeSteps = 7
SerieDesplazada = prepare_dataframe(Datos, TimeSteps)
SerieDesplazada
# Out:
#        Q_Ventas  Q_Ventas(t-1)  Q_Ventas(t-2)  Q_Ventas(t-3)  Q_Ventas(t-4)  \
# Fecha
# 1-13         50           72.0           66.0           58.0           60.0
# 1-14         53           50.0           72.0           66.0           58.0
# 1-15         63           53.0           50.0           72.0           66.0
# 1-16         72           63.0           53.0           50.0           72.0
# 1-17         38           72.0           63.0           53.0           50.0
# ...         ...            ...            ...            ...            ...
# 14-19       117          111.0          106.0           81.0          117.0
# 14-20        92          117.0          111.0          106.0           81.0
# 14-21        39           92.0          117.0          111.0          106.0
# 14-22        13           39.0           92.0          117.0          111.0
# 14-23         9           13.0           39.0           92.0          117.0
#
#        Q_Ventas(t-5)  Q_Ventas(t-6)  Q_Ventas(t-7)
# Fecha
# 1-13            68.0           29.0           10.0
# 1-14            60.0           68.0           29.0
# 1-15            58.0           60.0           68.0
# 1-16            66.0           58.0           60.0
# 1-17            72.0           66.0           58.0
# ...              ...            ...            ...
# 14-19          108.0           73.0          108.0
# 14-20          117.0          108.0           73.0
# 14-21           81.0          117.0          108.0
# 14-22          106.0           81.0          117.0
# 14-23          111.0          106.0           81.0
#
# [2971 rows x 8 columns]

# %% [markdown]
# Convierto a numpy para usar arrays

# %%
DesplazadaNp = SerieDesplazada.to_numpy()

DesplazadaNp
# Out:
# array([[ 50.,  72.,  66., ...,  68.,  29.,  10.],
#        [ 53.,  50.,  72., ...,  60.,  68.,  29.],
#        [ 63.,  53.,  50., ...,  58.,  60.,  68.],
#        ...,
#        [ 39.,  92., 117., ...,  81., 117., 108.],
#        [ 13.,  39.,  92., ..., 106.,  81., 117.],
#        [  9.,  13.,  39., ..., 111., 106.,  81.]])

# %% [markdown]
# Obsérvese que se tiene el dataset en forma: observaciones, número de columnas

# %%
DesplazadaNp.shape
# Out:
# (2971, 8)

# %% [markdown]
# Escalado de data. Deboi pasar antes de array ya que el escaler no sirve para df, o si sirve, pero toca dar más vuelta.

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(-1, 1))
DesplazadaNp = scaler.fit_transform(DesplazadaNp)

DesplazadaNp
# Out:
# array([[-0.71757925, -0.5907781 , -0.62536023, ..., -0.61383285,
#         -0.83861671, -0.9481268 ],
#        [-0.70028818, -0.71757925, -0.5907781 , ..., -0.65994236,
#         -0.61383285, -0.83861671],
#        [-0.6426513 , -0.70028818, -0.71757925, ..., -0.67146974,
#         -0.65994236, -0.61383285],
#        ...,
#        [-0.78097983, -0.47550432, -0.3314121 , ..., -0.5389049 ,
#         -0.3314121 , -0.3832853 ],
#        [-0.93083573, -0.78097983, -0.47550432, ..., -0.39481268,
#         -0.5389049 , -0.3314121 ],
#        [-0.95389049, -0.93083573, -0.78097983, ..., -0.36599424,
#         -0.39481268, -0.5389049 ]])

# %%
X = DesplazadaNp[:, 1:]
y = DesplazadaNp[:, 0]

# %% [markdown]
# Creo lotes de 7-1, es decir, 7 datos y predigo 1. Luego el predicho pasa a ser parte del nuevo lote y asi sucesivamente.

# %%
X[0], y[0]
# Out:
# (array([-0.5907781 , -0.62536023, -0.67146974, -0.65994236, -0.61383285,
#         -0.83861671, -0.9481268 ]),
#  -0.7175792507204612)

# %%
X.shape, y.shape
# Out:
# ((2971, 7), (2971,))

# %% [markdown]
# Crea una copia de los array anterioes pero girando la data. observe que el primer array tiene la estructura del anterior, pero del revés. Las redes LSTM (Long Short-Term Memory) están diseñadas para capturar dependencias a largo plazo en secuencias de datos. Invertir las secuencias temporales puede ser una técnica útil en ciertos casos para permitir que el modelo capte patrones en ambas direcciones (hacia adelante y hacia atrás en el tiempo).Al invertir las secuencias, se puede entrenar el modelo para aprender las dependencias temporales de manera más robusta. Esto es útil especialmente cuando se combinan con modelos bidireccionales (Bidirectional LSTM), aunque en este ejemplo específico no se menciona el uso de una capa bidireccional.

# %%
X = dc(np.flip(X, axis=1))
X
# Out:
# array([[-0.9481268 , -0.83861671, -0.61383285, ..., -0.67146974,
#         -0.62536023, -0.5907781 ],
#        [-0.83861671, -0.61383285, -0.65994236, ..., -0.62536023,
#         -0.5907781 , -0.71757925],
#        [-0.61383285, -0.65994236, -0.67146974, ..., -0.5907781 ,
#         -0.71757925, -0.70028818],
#        ...,
#        [-0.3832853 , -0.3314121 , -0.5389049 , ..., -0.36599424,
#         -0.3314121 , -0.47550432],
#        [-0.3314121 , -0.5389049 , -0.39481268, ..., -0.3314121 ,
#         -0.47550432, -0.78097983],
#        [-0.5389049 , -0.39481268, -0.36599424, ..., -0.47550432,
#         -0.78097983, -0.93083573]])

# %%
X.shape
# Out:
# (2971, 7)

# %%
X[0]
# Out:
# array([-0.9481268 , -0.83861671, -0.61383285, -0.65994236, -0.67146974,
#        -0.62536023, -0.5907781 ])

# %% [markdown]
# Defino un bloque para Training.

# %%
split_index = int(len(X) * 0.95)

split_index
# Out:
# 2822

# %%
len(Datos)
# Out:
# 2978

# %%
Datos.describe()
# Out:
#           Q_Ventas  Q_Ventas(t-1)  Q_Ventas(t-2)  Q_Ventas(t-3)  \
# count  2978.000000    2977.000000    2976.000000    2975.000000
# mean     88.694090      88.720860      88.746304      88.763025
# std      62.929562      62.923172      62.918428      62.922391
# min       1.000000       1.000000       1.000000       1.000000
# 25%      42.000000      42.000000      42.000000      42.000000
# 50%      82.000000      82.000000      82.500000      83.000000
# 75%     117.000000     117.000000     117.000000     117.000000
# max     348.000000     348.000000     348.000000     348.000000
#
#        Q_Ventas(t-4)  Q_Ventas(t-5)  Q_Ventas(t-6)  Q_Ventas(t-7)
# count    2974.000000    2973.000000    2972.000000    2971.000000
# mean       88.761937      88.752439      88.744953      88.739145
# std        62.932944      62.941399      62.950667      62.960468
# min         1.000000       1.000000       1.000000       1.000000
# 25%        42.000000      42.000000      42.000000      42.000000
# 50%        82.500000      82.000000      82.000000      82.000000
# 75%       117.000000     117.000000     117.000000     117.000000
# max       348.000000     348.000000     348.000000     348.000000

# %% [markdown]
# Sepra el dataset en Trainig y test.

# %%
X_train = X[:split_index]
X_test = X[split_index:]

y_train = y[:split_index]
y_test = y[split_index:]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2822, 7), (149, 7), (2822,), (149,))

# %% [markdown]
# Acá es importante recordar que se había creado x y y antes y tenían el mismo largo, solo que el train tiene 7 variables mientras que y solo tenía 1. Se deben crear subsets del mismo tamaño para la coherencia del modelado.

# %%
len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (2822, 149, 2822, 149)

# %% [markdown]
# Recordar que los modelos recurrentes requieren la estructura samples, timesteps, features. sine qua non

# %%
X_train = X_train.reshape((-1, TimeSteps, 1))
X_test = X_test.reshape((-1, TimeSteps, 1))

y_train = y_train.reshape((-1, 1))
y_test = y_test.reshape((-1, 1))

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((2822, 7, 1), (149, 7, 1), (2822, 1), (149, 1))

# %% [markdown]
# Creo tensores. Esto convierte arrays a tipo tensor que es necesario para modelar. El .float es fundamental también dado que pytorch espera .flotante.

# %%
X_train = torch.tensor(X_train).float()
y_train = torch.tensor(y_train).float()
X_test = torch.tensor(X_test).float()
y_test = torch.tensor(y_test).float()

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([2822, 7, 1]),
#  torch.Size([149, 7, 1]),
#  torch.Size([2822, 1]),
#  torch.Size([149, 1]))

# %% [markdown]
# Convierto los subsets en estructura de serie de tiempo para usarlo en pytorch, esto se hace para mejorar eficiencia

# %%
from torch.utils.data import Dataset

class TimeSeriesDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return self.X[i], self.y[i]

train_dataset = TimeSeriesDataset(X_train, y_train)
test_dataset = TimeSeriesDataset(X_test, y_test)

# %%
train_dataset

# %% [markdown]
# Batchsize indica el tamaño de minilotes que irá tomando el modelo. Impacta el rendimiento del modelo. Dataloader es propio de pytorch para la gestión del subset

# %%
from torch.utils.data import DataLoader

batch_size = 16

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
for _, batch in enumerate(train_loader):
    x_batch, y_batch = batch[0].to(device), batch[1].to(device)
    print(x_batch.shape, y_batch.shape)
    break
# Out:
# torch.Size([16, 7, 1]) torch.Size([16, 1])

# %% [markdown]
# Creo el modelo,

# %%
class GRUModel(nn.Module):
    def __init__(self, input_size, hidden_size, output_size, num_layers):
        super(GRUModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.gru = nn.GRU(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).requires_grad_()
        out, _ = self.gru(x, h0.detach())
        out = self.fc(out[:, -1, :])
        return out

# %%
input_size = 1
hidden_size = 4
output_size = 1
num_layers = 1

# %%
model = GRUModel(input_size, hidden_size, output_size, num_layers)

# %%
# Agregar listas para almacenar la pérdida
train_losses = []
val_losses = []

# %% [markdown]
# Entrenamiento...

# %%
def train_one_epoch():
    model.train(True)
    print(f'Epoch: {epoch + 1}')
    running_loss = 0.0 # Inicializa una variable para acumular la pérdida a lo largo de los lotes en la época.

    for batch_index, batch in enumerate(train_loader): # Itera sobre los lotes de datos proporcionados por el train_loader. enumerate proporciona tanto el índice del lote (batch_index) como el lote en sí (batch).
        x_batch, y_batch = batch[0].to(device), batch[1].to(device) # Extrae las características (x_batch) y las etiquetas (y_batch) del lote y las mueve al dispositivo especificado (CPU o GPU).

        output = model(x_batch) # Realiza el paso hacia adelante (forward pass) a través del modelo con las características del lote, produciendo las predicciones (output).
        loss = loss_function(output, y_batch) # Calcula la pérdida entre las predicciones del modelo y las etiquetas verdaderas utilizando la función de pérdida definida (loss_function).
        running_loss += loss.item() # Acumula la pérdida del lote actual en running_loss

        optimizer.zero_grad() # Resetea los gradientes de los parámetros del modelo. Esto es necesario porque por defecto, PyTorch acumula los gradientes.
        loss.backward() # Calcula los gradientes de la pérdida respecto a los parámetros del modelo (backward pass).
        optimizer.step() # Actualiza los parámetros del modelo utilizando los gradientes calculados.

        # Calcular la pérdida promedio del epoch
        epoch_loss = running_loss / len(train_loader)
        train_losses.append(epoch_loss)


        if batch_index % 100 == 99:  # print every 100 batches
            avg_loss_across_batches = running_loss / 100 #Comprueba si el índice del lote es un múltiplo de 100 (menos 1 debido a que batch_index comienza en 0). Esto asegura que se imprime la pérdida cada 100 lotes.

            print('Batch {0}, Loss: {1:.3f}'.format(batch_index+1,
                                                    avg_loss_across_batches))
            running_loss = 0.0
    print()

# %% [markdown]
# Validación...

# %%
def validate_one_epoch():
    model.train(False) # Pone el modelo en modo de evaluación (en contraste con el modo de entrenamiento que se usa con model.train(True)). Esto asegura que capas como Dropout y BatchNorm se comporten de manera determinista durante la evaluación.
    running_loss = 0.0

    for batch_index, batch in enumerate(test_loader):
        x_batch, y_batch = batch[0].to(device), batch[1].to(device)

        with torch.no_grad(): # Temporalmente deshabilita el cálculo y almacenamiento de gradientes en PyTorch para reducir el uso de memoria y acelerar el cálculo. Esto es útil durante la evaluación cuando no necesitamos ajustar los pesos del modelo.
            output = model(x_batch)
            loss = loss_function(output, y_batch)
            running_loss += loss.item()

    # Calcular la pérdida promedio del epoch
    epoch_loss = running_loss / len(test_loader)
    val_losses.append(epoch_loss)

    avg_loss_across_batches = running_loss / len(test_loader)
    val_losses.append(epoch_loss)

    print('Val Loss: {0:.3f}'.format(avg_loss_across_batches))
    print('***************************************************')
    print()

# %%
learning_rate = 0.001
num_epochs = 100
loss_function = nn.MSELoss() #  calcula el error cuadrático medio entre las predicciones y las etiquetas verdaderas.
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

for epoch in range(num_epochs):
    train_one_epoch()
    validate_one_epoch()
# Out:
# Epoch: 1
# Batch 100, Loss: 0.150
#
# Val Loss: 0.070
# ***************************************************
#
# Epoch: 2
# Batch 100, Loss: 0.067
#
# Val Loss: 0.045
# ***************************************************
#
# Epoch: 3
# Batch 100, Loss: 0.045
#
# Val Loss: 0.039
# ***************************************************
#
# Epoch: 4
# Batch 100, Loss: 0.036
#
# Val Loss: 0.034
# ***************************************************
#
# Epoch: 5
# Batch 100, Loss: 0.035
#
# Val Loss: 0.032
# ***************************************************
#
# Epoch: 6
# Batch 100, Loss: 0.032
#
# Val Loss: 0.031
# ***************************************************
#
# Epoch: 7
# Batch 100, Loss: 0.034
#
# Val Loss: 0.030
# ***************************************************
#
# Epoch: 8
# Batch 100, Loss: 0.029
#
# Val Loss: 0.030
# ***************************************************
#
# Epoch: 9
# Batch 100, Loss: 0.030
#
# Val Loss: 0.029
# ***************************************************
#
# Epoch: 10
# Batch 100, Loss: 0.033
#
# Val Loss: 0.029
# ***************************************************
#
# Epoch: 11
# Batch 100, Loss: 0.030
#
# Val Loss: 0.029
# ***************************************************
#
# Epoch: 12
# Batch 100, Loss: 0.031
#
# Val Loss: 0.028
# ***************************************************
#
# Epoch: 13
# Batch 100, Loss: 0.031
#
# Val Loss: 0.028
# ***************************************************
#
# Epoch: 14
# Batch 100, Loss: 0.030
#
# Val Loss: 0.028
# ***************************************************
#
# Epoch: 15
# Batch 100, Loss: 0.029
#
# Val Loss: 0.027
# ***************************************************
#
# Epoch: 16
# Batch 100, Loss: 0.028
#
# Val Loss: 0.027
# ***************************************************
#
# Epoch: 17
# Batch 100, Loss: 0.030
#
# Val Loss: 0.027
# ***************************************************
#
# Epoch: 18
# Batch 100, Loss: 0.030
#
# Val Loss: 0.027
# ***************************************************
#
# Epoch: 19
# Batch 100, Loss: 0.030
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 20
# Batch 100, Loss: 0.029
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 21
# Batch 100, Loss: 0.031
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 22
# Batch 100, Loss: 0.030
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 23
# Batch 100, Loss: 0.029
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 24
# Batch 100, Loss: 0.026
#
# Val Loss: 0.027
# ***************************************************
#
# Epoch: 25
# Batch 100, Loss: 0.030
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 26
# Batch 100, Loss: 0.028
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 27
# Batch 100, Loss: 0.027
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 28
# Batch 100, Loss: 0.028
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 29
# Batch 100, Loss: 0.027
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 30
# Batch 100, Loss: 0.027
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 31
# Batch 100, Loss: 0.028
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 32
# Batch 100, Loss: 0.029
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 33
# Batch 100, Loss: 0.028
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 34
# Batch 100, Loss: 0.027
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 35
# Batch 100, Loss: 0.029
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 36
# Batch 100, Loss: 0.026
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 37
# Batch 100, Loss: 0.025
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 38
# Batch 100, Loss: 0.027
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 39
# Batch 100, Loss: 0.026
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 40
# Batch 100, Loss: 0.027
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 41
# Batch 100, Loss: 0.027
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 42
# Batch 100, Loss: 0.025
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 43
# Batch 100, Loss: 0.027
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 44
# Batch 100, Loss: 0.027
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 45
# Batch 100, Loss: 0.028
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 46
# Batch 100, Loss: 0.027
#
# Val Loss: 0.027
# ***************************************************
#
# Epoch: 47
# Batch 100, Loss: 0.026
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 48
# Batch 100, Loss: 0.026
#
# Val Loss: 0.026
# ***************************************************
#
# Epoch: 49
# Batch 100, Loss: 0.025
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 50
# Batch 100, Loss: 0.027
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 51
# Batch 100, Loss: 0.027
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 52
# Batch 100, Loss: 0.026
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 53
# Batch 100, Loss: 0.024
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 54
# Batch 100, Loss: 0.026
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 55
# Batch 100, Loss: 0.027
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 56
# Batch 100, Loss: 0.025
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 57
# Batch 100, Loss: 0.028
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 58
# Batch 100, Loss: 0.028
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 59
# Batch 100, Loss: 0.024
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 60
# Batch 100, Loss: 0.026
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 61
# Batch 100, Loss: 0.026
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 62
# Batch 100, Loss: 0.027
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 63
# Batch 100, Loss: 0.027
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 64
# Batch 100, Loss: 0.027
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 65
# Batch 100, Loss: 0.026
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 66
# Batch 100, Loss: 0.024
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 67
# Batch 100, Loss: 0.025
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 68
# Batch 100, Loss: 0.024
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 69
# Batch 100, Loss: 0.025
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 70
# Batch 100, Loss: 0.026
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 71
# Batch 100, Loss: 0.027
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 72
# Batch 100, Loss: 0.026
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 73
# Batch 100, Loss: 0.027
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 74
# Batch 100, Loss: 0.026
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 75
# Batch 100, Loss: 0.026
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 76
# Batch 100, Loss: 0.026
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 77
# Batch 100, Loss: 0.026
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 78
# Batch 100, Loss: 0.027
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 79
# Batch 100, Loss: 0.026
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 80
# Batch 100, Loss: 0.027
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 81
# Batch 100, Loss: 0.026
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 82
# Batch 100, Loss: 0.027
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 83
# Batch 100, Loss: 0.025
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 84
# Batch 100, Loss: 0.026
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 85
# Batch 100, Loss: 0.026
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 86
# Batch 100, Loss: 0.026
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 87
# Batch 100, Loss: 0.026
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 88
# Batch 100, Loss: 0.025
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 89
# Batch 100, Loss: 0.025
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 90
# Batch 100, Loss: 0.025
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 91
# Batch 100, Loss: 0.026
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 92
# Batch 100, Loss: 0.025
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 93
# Batch 100, Loss: 0.026
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 94
# Batch 100, Loss: 0.024
#
# Val Loss: 0.025
# ***************************************************
#
# Epoch: 95
# Batch 100, Loss: 0.023
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 96
# Batch 100, Loss: 0.026
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 97
# Batch 100, Loss: 0.026
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 98
# Batch 100, Loss: 0.026
#
# Val Loss: 0.024
# ***************************************************
#
# Epoch: 99
# Batch 100, Loss: 0.026
#
# Val Loss: 0.023
# ***************************************************
#
# Epoch: 100
# Batch 100, Loss: 0.025
#
# Val Loss: 0.024
# ***************************************************

# %%
plt.figure(figsize=(10, 6))
#plt.plot(train_losses, label='Training Loss')
plt.plot(val_losses, label='Validation Loss',color='black')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Validation Loss')
plt.legend()
plt.show()

# %%
with torch.no_grad():
    predicted = model(X_train.to(device)).to('cpu').numpy()

plt.plot(y_train, label='Real')
plt.plot(predicted, label='Predicción')
plt.xlabel('Intervalo')
plt.ylabel('Q_Ventas_Escalada')
plt.legend()
plt.show()

# %% [markdown]
# Escalado inverso para las predicciones

# %%
#train_predictions = predicted.flatten() # flatten() se utiliza para convertir predicted en una matriz unidimensional (aplanada).

#Ajuste = np.zeros((X_train.shape[0], TimeSteps+1)) #  Crea una matriz de ceros de tamaño (X_train.shape[0], lookback+1
#Ajuste[:, 0] = train_predictions # Asigna las predicciones a la primera columna
#Ajuste = scaler.inverse_transform(Ajuste) # Escalado inverso

#train_predictions = dc(Ajuste[:, 0])
#train_predictions

# %%
#Ajuste = np.zeros((X_train.shape[0], TimeSteps+1))
#Ajuste[:, 0] = y_train.flatten()
#Ajuste = scaler.inverse_transform(Ajuste)

#new_y_train = dc(Ajuste[:, 0])
#new_y_train
# Out:
# array([ 50.00000089,  53.00000137,  62.99999607, ..., 283.00000346,
#        320.00000244, 306.99999693])

# %%
test_predictions = model(X_test.to(device)).detach().cpu().numpy().flatten()

Ajuste = np.zeros((X_test.shape[0], TimeSteps+1))
Ajuste[:, 0] = test_predictions
Ajuste = scaler.inverse_transform(Ajuste)

test_predictions = dc(Ajuste[:, 0])
test_predictions
# Out:
# array([ 2.82889030e+02,  2.11570626e+02,  1.47687064e+02,  6.20369320e+01,
#         6.06293514e+00, -7.85716593e+00,  1.87546220e+01,  7.88107440e+01,
#         1.20604057e+02,  1.08190802e+02,  1.11597820e+02,  7.29411688e+01,
#         6.91061412e+01,  9.74727364e+01,  1.03576539e+02,  6.21598085e+01,
#         2.74761190e+01,  1.09649571e+02,  1.42925361e+02,  1.37598973e+02,
#         7.76665295e+01,  2.27371387e+01, -2.64094013e+00,  1.02185257e+01,
#         5.18351351e+01,  8.09549001e+01,  8.61517564e+01,  1.12708213e+02,
#         1.21167064e+02,  1.23471501e+02,  9.51645502e+01,  1.07101402e+02,
#         8.20854122e+01,  9.73586500e+01,  1.27476418e+02,  1.47876361e+02,
#         1.53130289e+02,  1.30672217e+02,  8.23231611e+01,  5.15834563e+01,
#         1.57792341e+01, -2.16438890e-01,  1.85702037e+01,  5.13877659e+01,
#         9.15082944e+01,  1.36661675e+02,  1.26284302e+02,  1.22888970e+02,
#         9.42141750e+01,  5.79827596e+01,  5.39012446e+01,  5.48629850e+01,
#         9.38645320e+01,  8.81877362e+01,  7.51816448e+01,  7.83279451e+01,
#         4.36334592e+01,  2.33778405e+01,  1.86588502e+01,  2.32260494e+01,
#         3.33762634e+01,  3.44836521e+01,  5.42356132e+01,  5.58264214e+01,
#         6.11030203e+01,  6.41719049e+01,  6.30059527e+01,  6.41341691e+01,
#         5.25852696e+01,  6.41161026e+01,  7.02583703e+01,  6.49323291e+01,
#         7.41042047e+01,  6.80508318e+01,  6.00249494e+01,  3.53039221e+01,
#         4.40257072e+00,  7.94102752e+00,  3.86070395e+01,  6.41728873e+01,
#         8.34090501e+01,  9.49236057e+01,  9.20776715e+01,  7.84532002e+01,
#         7.90240251e+01,  8.31151163e+01,  7.62618563e+01,  1.10361810e+02,
#         1.13417886e+02,  1.41815573e+02,  1.65977989e+02,  1.26269710e+02,
#         6.67316096e+01,  5.11389827e+01,  7.95778060e+00,  1.66979074e-01,
#         3.97224222e+01,  6.39405159e+01,  1.00119480e+02,  9.51885422e+01,
#         9.73433758e+01,  7.43459454e+01,  7.64726969e+01,  7.17343164e+01,
#         6.48544170e+01,  6.85128651e+01,  9.87442381e+01,  1.06918147e+02,
#         9.42844913e+01,  7.14928963e+01,  4.84699072e+01,  4.00937614e+01,
#         1.53101169e+01,  3.55841210e+00,  5.21954607e+01,  1.14543879e+02,
#         1.98516147e+02,  2.33430119e+02,  1.99511373e+02,  2.13972236e+02,
#         1.97984516e+02,  2.01015763e+02,  1.96152515e+02,  2.34249024e+02,
#         2.60822734e+02,  2.10058355e+02,  2.48113426e+02,  2.24108210e+02,
#         1.32834605e+02,  7.78126949e+01,  5.70573264e+00, -1.17246449e+01,
#         1.93169773e+01,  6.16237411e+01,  1.07351152e+02,  8.46153027e+01,
#         1.08655524e+02,  8.34388023e+01,  8.90854788e+01,  6.26404461e+01,
#         8.78991024e+01,  1.08760169e+02,  7.39334061e+01,  8.53485498e+01,
#         9.94945795e+01,  1.05647106e+02,  8.05315229e+01,  2.93558350e+01,
#         2.85553634e-01])

# %%
Ajuste = np.zeros((X_test.shape[0], TimeSteps+1))
Ajuste[:, 0] = y_test.flatten()
Ajuste = scaler.inverse_transform(Ajuste)

new_y_test = dc(Ajuste[:, 0])
new_y_test
# Out:
# array([225.00000113, 176.99999997, 100.99999866,  34.99999851,
#         16.00000238,  22.00000334,  48.99999729,  85.99999627,
#        100.00000022, 123.00000043,  82.00000253,  89.00000192,
#        113.00000057, 110.99999852,  71.00000423,  40.99999946,
#        134.99999975, 133.0000003 , 144.99999962,  90.00000036,
#         36.99999538,  11.9999983 ,  10.00000143,  22.00000334,
#         40.99999946,  68.00000376, 116.99999948, 126.99999934,
#        136.00000077, 109.00000165, 127.99999778,  94.99999771,
#        117.99999791, 141.99999914, 159.99999942, 165.99999973,
#        146.00000064, 102.00000226,  73.0000011 ,  28.99999756,
#         10.00000143,  11.00000504,  17.99999925,  56.99999511,
#        120.99999839, 123.00000043, 134.99999975, 107.99999805,
#         74.00000471,  73.0000011 ,  65.00000328, 103.0000007 ,
#         86.99999988,  85.99999627,  92.0000024 ,  48.99999729,
#         36.00000212,  22.9999966 ,  13.00000191,  13.99999517,
#         11.00000504,  39.00000259,  39.99999586,  62.99999607,
#         70.00000063,  71.00000423,  74.99999797,  59.99999559,
#         76.00000158,  74.00000471,  70.00000063,  83.9999994 ,
#         73.0000011 ,  68.99999702,  40.99999946,   8.00000456,
#          8.00000456,  13.00000191,  27.00000069,  62.99999607,
#         90.00000036,  97.99999818,  90.00000036,  94.99999771,
#         96.00000131,  86.99999988, 126.99999934, 120.99999839,
#        157.99999996, 179.00000007, 139.00000125,  86.99999988,
#         74.99999797,  16.00000238,  11.9999983 ,  27.00000069,
#         24.00000021,  80.99999893,  83.9999994 , 106.99999961,
#         83.9999994 ,  93.99999927,  82.9999958 ,  76.00000158,
#         79.99999532, 109.00000165, 112.00000213, 104.99999757,
#         85.00000301,  62.0000028 ,  53.00000137,  16.99999565,
#          2.99999687,  37.99999899,  71.00000423, 195.99999997,
#        232.99999896, 197.99999943, 226.999998  , 210.99999977,
#        219.00000018, 214.00000025, 256.9999976 , 283.00000346,
#        222.00000066, 274.99999529, 238.99999991, 159.99999942,
#        116.00000104,  28.99999756,  13.00000191,  22.9999966 ,
#         28.00000429,  74.99999797,  68.00000376, 123.99999887,
#         89.00000192, 107.99999805,  73.0000011 , 107.99999805,
#        116.99999948,  80.99999893, 106.00000118, 110.99999852,
#        116.99999948,  92.0000024 ,  39.00000259,  13.00000191,
#          8.99999782])

# %%
plt.plot(new_y_test, label='Data real')
plt.plot(test_predictions, label='Predicción')
plt.xlabel('Intervalo')
plt.ylabel('Q_Ventas')
plt.legend()
plt.show()

# %%
Media=np.mean(new_y_test)

# %%
Media
# Out:
# 90.28859057952496

# %% [markdown]
# Lo anterior es la media del test.

# %%
def calculate_mse(predictions, targets):
    mse = np.mean((predictions - targets) ** 2)
    return mse

# %%
MSE = calculate_mse(test_predictions, new_y_test)
print(f'MSE: {MSE:.2f}')
# Out:
# MSE: 736.70

# %%
# Suponiendo train_predictions y y_train son numpy arrays
def calculate_rmse(predictions, targets):
    mse = np.mean((predictions - targets) ** 2)
    rmse = np.sqrt(mse)
    return rmse

# Ejemplo de uso
RSME = calculate_rmse(test_predictions, new_y_test)
print(f'RMSE: {RSME:.2f}')
# Out:
# RMSE: 27.14
